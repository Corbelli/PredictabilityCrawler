# %%
using DataFrames, PrevisibilityCrawler
attr = pty.attr
bestc = "#62AD7A"
headercolor = "#084493"
headercolor = "#BC2024"
bestc = "#5A95D6"
badc = "#FC4C47"
drawc = "D1D1D6"

# function printtable(names, rows, colors, width::Int64=800, height::Int64=600)
#     table = pty.table(header=attr(values=names,
#                                   align=["left", "center"],
#                                   fill_color=headercolor, line=attr(width=1, color="black"),
#                                   font=attr(family="Arial", size=14, color="white")),
#                       cells=attr(values=rows, align=["left", "center"],
#                                  line=attr(color="black", width=1),
#                                  font=attr(family="Arial", size=11, color="black"),
#                                  fill_color=colors))
#     pty.plot(table, pty.Layout(width=width,height=height, margin=attr(l=20, r=100, b=10)))
# end
# Out:
# "D1D1D6"

# %%
#knnregulartable
names = ["Configuration" "Avg Mean Value" "Avg Best Value" "Avg Purity" "Avg Relative Size"]
rows = ["KNN GA" 0.29 0.34 0.94 0.50
        "Regular GA"  0.42 0.47 0.95 0.26]
colors = fill("white", size([names; rows]))
colors[1, 5] = bestc
printtable(names, rows, colors, 800, 200)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields height, margin, and width"

# %%
#evol_lowsnrtable
names = ["Configuration" "Avg Mean Value" "Avg Best Value" "Avg Purity" "Avg Relative Size"]
rows = ["10% Total Purity" 0.09 0.09 0.11 9.22
        "20% Total Purity" 0.24 0.27 0.85 0.98 
        "30% Total Purity" 0.40 0.45 0.96 0.40
        "40% Total Purity" 0.34 0.39 0.97 0.45 
        "50% Total Purity" 0.37 0.41 0.98 0.33
        "70% Total Purity" 0.39 0.42 0.99 0.25 
        "90% Total Purity" 0.44 0.47 1.0 0.16 
        "100% Total Purity" 0.47 0.49 1.0 0.13]
colors = fill("white", size([names; rows]))
colors[2:4, 4:5] = fill(bestc, (3,2))
printtable(names, rows, colors)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields height, margin, and width"

# %%
#evol_03table
names = ["Configuration" "Avg Mean Value" "Avg Best Value" "Avg Purity" "Avg Relative Size"]
rows = ["20% Total Purity" 0.28 0.29 0.20 4.77 
        "30% Total Purity" 0.37 0.40 0.93 0.72 
        "40% Total Purity" 0.37 0.40 0.97 0.747 
        "50% Total Purity" 0.39 0.41 0.98 0.68 
        "70% Total Purity" 0.44 0.46 0.99 0.67 
        "90% Total Purity" 0.53 0.54 1.0 0.49 
        "100% Total Purity" 0.56 0.57 1.0 0.91 ]
colors = fill("white", size([names; rows]))
colors[2:7, 4:5] = fill(bestc, (6,2))
# colors[7, 4:5] = fill(bestc, 2)

printtable(names, rows, colors)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields height, margin, and width"

# %%
#restarttable
names = ["Configuration" "Avg Mean Value" "Avg Best Value" "Avg Purity" "Avg Relative Size"]
rows = ["Regular GA" 0.27 0.31 0.92 0.75 
        "GA with Reestartings" 0.21 0.24 0.90 0.80]
colors = fill("white", size([names; rows]))

printtable(names, rows, colors)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields height, margin, and width"

# %%
#crossovertable
names = ["Configuration" "Avg Mean Value" "Avg Best Value" "Avg Purity" "Avg Relative Size"]
rows = ["Single-Point Crossover" 0.18 0.20 0.59 1.67 
        "Two-Point Crossover" 0.12 0.13 0.57 1.76 
]
colors = fill("white", size([names; rows]))

printtable(names, rows, colors)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields height, margin, and width"

# %%
#pso30perttable
names = ["Configuration" "Avg Mean Value" "Avg Best Value" "Avg Purity" "Avg Relative Size"]
rows = ["Pertubed PSO" 0.25 0.31 0.990 0.80 
        "Regular PSO" 0.15 0.21 0.76 1.34 
]
colors = fill("white", size([names; rows]))
colors[1, 4:5] = fill(bestc, 2)
printtable(names, rows, colors)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields height, margin, and width"

# %%
#inits_3001table
names = ["Configuration" "Avg Mean Value" "Avg Best Value" "Avg Purity" "Avg Relative Size"]
rows = ["Random Init" 0.25 0.31 0.99 0.80
        "Group Init" 0.16 0.19 0.55 2.18
]
colors = fill("white", size([names; rows]))
colors[1, 4:5] = fill(bestc, 2)
printtable(names, rows, colors)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields height, margin, and width"

# %%
#pso01table
names = ["Configuration" "Avg Mean Value" "Avg Best Value" "Avg Purity" "Avg Relative Size"]
rows = ["20% Total Purity" 0.10 0.10 0.20 5.0 
        "30% Total Purity" 0.25 0.31 0.99 0.80
        "40% Total Purity" 0.38 0.43 1.0 0.43
        "50% Total Purity" 0.35 0.40 1.0 0.35
        "70% Total Purity" 0.41 0.46 1.0 0.31
        "90% Total Purity" 0.38 0.42 1.0 0.35
        "100% Total Purity" 0.42 0.46 1.0 0.32
]
colors = fill("white", size([names; rows]))
colors[2, 4:5] = fill(bestc, 2)
colors[1, 4:5] = fill(badc, 2)

printtable(names, rows, colors)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields height, margin, and width"

# %%
#pso_03table
names = ["Configuration" "Avg Mean Value" "Avg Best Value" "Avg Purity" "Avg Relative Size"]
rows = ["20% Total Purity" 0.30 0.30 0.2 5.0 
        "30% Total Purity" 0.30 0.30 0.3 3.33
        "40% Total Purity" 0.35 0.39 0.91 0.99 
        "50% Total Purity" 0.40 0.43 0.99 0.94 
        "70% Total Purity" 0.50 0.51 1.0 0.98 
        "90% Total Purity" 0.55 0.56 1.0 0.97
        "100% Total Purity" 0.61 0.62 1.0 0.99
]
colors = fill("white", size([names; rows]))
colors[1:2, 4:5] = fill(badc, (2,2))
colors[3:7, 4:5] = fill(bestc, (5,2))

printtable(names, rows, colors)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields height, margin, and width"

# %%
#Features Table
names = ["Feature" "Function"]
rows = [
    "Last 9 Absolute Log Returns" "Heteroscedasticity of Returns"
    "Last 3 Log Returns to the 3 last Support levels" "Price Action Indicators"
    "Last 3 Log Returns to the 3 last Resistance levels" "Price Action Indicators"
    "Pivot Points" "Price Action Indicators"
    "Last 3 Log Returns to the Upper Boillinger Band" "Reversal Indicators"
    "Last 3 Log Returns to the Lower Boillinger Band" "Reversal Indicators"
    "Last 3 Log Returns to the Mid Boillinger Band" "Reversal Indicators"
    "Last 3 Volumes of Stock Traded in each interval" "Momentum Indicators"
    "Angular Coefficient from the 60-Minute Series" "Trend Following Indicators"
    "Last 3 values of the MACD Technical Indicator" "Momentum Indicators"
    "Last 3 values of the RSI Technical Indicator" "Momentum Indicators"
    "Last 3 Log Returns to the VWAP" "Trend Following Indicators"
    "Last 3 Log Returns to the EMA of 9 periods" "Trend Following Indicators"
    "Last 3 Log Returns to the EMA of 27 periods" "Trend Following Indicators"
    "Last 3 Log Returns to the EMA of 200 period" "Trend Following Indicators "
]
colors = fill("white", size([names; rows]))


printtable(names, rows, colors)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields margin and width"

# %%
#featuretable
names = ["Feature" "Function"]
rows = [
    "Last 9 Absolute Log Returns" "Heteroscedasticity of Returns"
    "Last 3 Log Returns to the 3 last Support levels" "Price Action Indicators"
    "Last 3 Log Returns to the 3 last Resistance levels" "Price Action Indicators"
    "Pivot Points" "Price Action Indicators"
    "Last 3 Log Returns to the Upper Boillinger Band" "Reversal Indicators"
    "Last 3 Log Returns to the Lower Boillinger Band" "Reversal Indicators"
    "Last 3 Log Returns to the Mid Boillinger Band" "Reversal Indicators"
    "Last 3 Volumes of Stock Traded in each interval" "Momentum Indicators"
    "Angular Coefficient from the 60-Minute Series" "Trend Following Indicators"
    "Last 3 values of the MACD Technical Indicator" "Momentum Indicators"
    "Last 3 values of the RSI Technical Indicator" "Momentum Indicators"
    "Last 3 Log Returns to the VWAP" "Trend Following Indicators"
    "Last 3 Log Returns to the EMA of 9 periods" "Trend Following Indicators"
    "Last 3 Log Returns to the EMA of 27 periods" "Trend Following Indicators"
    "Last 3 Log Returns to the EMA of 200 period" "Trend Following Indicators "
]
colors = fill("white", size([names; rows]))


printtable(names, rows, colors)

# %%
#masebrfs3boosttable
names = ["Metric" "Whole Dataset" "Selected Samples"]
rows = [
    "Cross Validated MASE"  1.15 1.08 
]
colors = fill("white", size([names; rows]))
colors[1, 3] =  bestc
printtable(names, rows, colors)

# %%
#masebrfs3boosttesttable
names = ["Metric" "Whole Dataset" "Selected Samples"]
rows = [
    "Test Set MASE"  1.45 1.37
]
colors = fill("white", size([names; rows]))
colors[1, 3] = bestc
printtable(names, rows, colors)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields margin and width"

# %%
#finaltablevboost
names = ["Stock" "Selected Fraction" "Whole MAE" "Selected MAE" "Whole CDC" "Selected CDC" "Whole Naive" "Selected Naive" "Whole MASE" "Selected MASE"]
rows = [
  "BRFS3" 0.99 0.0051 0.0049 0.51 0.52 0.0036 0.0036 1.43 1.38
  "PETR4" 0.47 0.0056 0.0054 0.53 0.53 0.0033 0.0034 1.66 1.56
  "BBAS3" 0.84 0.0048 0.0045 0.52 0.52 0.0034 0.0033 1.44 1.38
  "BBDC4" 0.82 0.0041 0.0040 0.52 0.51 0.0031 0.0030 1.33 1.31
  "ITSA4" 0.97 0.0038 0.0037 0.55 0.56 0.0028 0.0028 1.38 1.36 
  "VALE3" 0.90 0.0040 0.0040 0.51 0.51 0.0032 0.0032 1.25 1.28
  "ITUB4" 0.55 0.0037 0.0035 0.51 0.51 0.0028 0.0027 1.33 1.28
  "ABEV3" 0.88 0.0039 0.0037 0.52 0.54 0.0029 0.0029 1.31 1.29 
  "RENT3" 0.65 0.0055 0.0056 0.53 0.54 0.0041 0.0040 1.35 1.37
  "KROT3" 0.83 0.0066 0.0063 0.55 0.54 0.0043 0.0043 1.51 1.44
  "B3SA3" 0.69 0.0045 0.0046 0.54 0.52 0.0035 0.0035 1.29 1.32 
  "CCRO3" 0.50 0.0058 0.0057 0.53 0.54 0.0042 0.0039 1.36 1.45
  "JBSS3" 0.76 0.0055 0.0055 0.55 0.54 0.0037 0.0037 1.47 1.47 
  "GGBR4" 0.51 0.0052 0.0049 0.55 0.55 0.0036 0.0036 1.42 1.36 
  "ESTC3" 0.81 0.0083 0.0079 0.52 0.53 0.0045 0.0045 1.83 1.76 
  "EMBR3" 0.42 0.0045 0.0038 0.54 0.53 0.0033 0.0030 1.35 1.29 
  "ELET3" 0.09 0.0073 0.0066 0.52 0.51 0.0051 0.0051 1.43 1.31
  "CMIG4" 0.95 0.0064 0.0064 0.55 0.55 0.0040 0.0039 1.61 1.63
  "ELET6" 0.90 0.0072 0.0064 0.52 0.51 0.0049 0.0049 1.46 1.30
  "CSNA3" 0.69 0.0055 0.0056 0.56 0.55 0.0043 0.0043 1.27 1.31  
]
colors = fill("white", size([names; rows]))
draws = [6, 13, 18]
winers = [[1,3], [2,3], [3,3], [4, 3], [5, 3], [7, 3], [8,3], [9,2], [10, 3], [11, 2], [12, 3], [14,3], [15,3], [16,3], [17,3], [19,3],[20, 2]]
colors[1:5, 4] = fill(bestc, 5)
colors[6, 3:4] = fill(drawc, 2)
colors[7:8, 4] = fill(bestc, 2)
colors[9, 3] = bestc
colors[10, 4] = bestc
colors[11, 3] = bestc
colors[12, 4] = bestc
colors[13, 3:4] = fill(drawc, 2)
colors[14:17, 4] = fill(bestc, 4)
colors[18, 3:4] = fill(drawc, 2)
colors[19, 4] = bestc
colors[20, 3] = bestc
printtable(names, rows, colors, 1230)
# Out:
# data: [
#   "table with fields cells, header, and type"
# ]
#
# layout: "layout with fields height, margin, and width"
