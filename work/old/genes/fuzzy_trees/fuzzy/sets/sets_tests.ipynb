# %% [markdown]
# # Triangular Set

# %%
include("triangular.jl")

# %%
a = Trig(0, 0.5, 1)
plot(a)

# %%
b = Trig(0.5, 0.7, 1.3)
c = Trig(1., 1.3, 1.5)
plot([a,b,c])

# %%
plot(even_range(0., 10., 7))
